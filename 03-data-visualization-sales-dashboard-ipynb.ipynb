# %% [markdown]
# # Sales Dashboard with Data Visualization
#
# ## Project Overview
#
# This is my third Python data science project.
#
# In this project, I use Pandas, Matplotlib, and Seaborn to create a simple sales dashboard.
#
# The goal is to practice:
#
# - Data visualization
# - Bar charts
# - Line charts
# - Pie charts
# - Scatter plots
# - Dashboard-style reporting
# - Business insights from charts
#
# This project builds on the previous Pandas sales analysis project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style="whitegrid")

# %%
sales_data = [
    {"Month": "Jan", "Product": "Laptop", "Category": "Electronics", "Region": "North", "Price": 1200, "Cost": 900, "Quantity": 5},
    {"Month": "Jan", "Product": "Mouse", "Category": "Accessories", "Region": "South", "Price": 25, "Cost": 10, "Quantity": 50},
    {"Month": "Jan", "Product": "Keyboard", "Category": "Accessories", "Region": "East", "Price": 75, "Cost": 35, "Quantity": 20},
    
    {"Month": "Feb", "Product": "Monitor", "Category": "Electronics", "Region": "North", "Price": 300, "Cost": 200, "Quantity": 12},
    {"Month": "Feb", "Product": "Headphones", "Category": "Accessories", "Region": "West", "Price": 100, "Cost": 45, "Quantity": 18},
    {"Month": "Feb", "Product": "Tablet", "Category": "Electronics", "Region": "South", "Price": 500, "Cost": 350, "Quantity": 9},
    
    {"Month": "Mar", "Product": "Webcam", "Category": "Accessories", "Region": "East", "Price": 80, "Cost": 40, "Quantity": 15},
    {"Month": "Mar", "Product": "Printer", "Category": "Office", "Region": "West", "Price": 250, "Cost": 180, "Quantity": 8},
    {"Month": "Mar", "Product": "Laptop", "Category": "Electronics", "Region": "North", "Price": 1200, "Cost": 900, "Quantity": 6},
    
    {"Month": "Apr", "Product": "Mouse", "Category": "Accessories", "Region": "South", "Price": 25, "Cost": 10, "Quantity": 65},
    {"Month": "Apr", "Product": "Keyboard", "Category": "Accessories", "Region": "East", "Price": 75, "Cost": 35, "Quantity": 25},
    {"Month": "Apr", "Product": "Monitor", "Category": "Electronics", "Region": "North", "Price": 300, "Cost": 200, "Quantity": 14},
    
    {"Month": "May", "Product": "Headphones", "Category": "Accessories", "Region": "West", "Price": 100, "Cost": 45, "Quantity": 22},
    {"Month": "May", "Product": "Tablet", "Category": "Electronics", "Region": "South", "Price": 500, "Cost": 350, "Quantity": 11},
    {"Month": "May", "Product": "Printer", "Category": "Office", "Region": "West", "Price": 250, "Cost": 180, "Quantity": 10},
    
    {"Month": "Jun", "Product": "Laptop", "Category": "Electronics", "Region": "North", "Price": 1200, "Cost": 900, "Quantity": 7},
    {"Month": "Jun", "Product": "Mouse", "Category": "Accessories", "Region": "South", "Price": 25, "Cost": 10, "Quantity": 70},
    {"Month": "Jun", "Product": "Webcam", "Category": "Accessories", "Region": "East", "Price": 80, "Cost": 40, "Quantity": 18}
]

# %%
df = pd.DataFrame(sales_data)

df
# Out:
#    Month     Product     Category Region  Price  Cost  Quantity
# 0    Jan      Laptop  Electronics  North   1200   900         5
# 1    Jan       Mouse  Accessories  South     25    10        50
# 2    Jan    Keyboard  Accessories   East     75    35        20
# 3    Feb     Monitor  Electronics  North    300   200        12
# 4    Feb  Headphones  Accessories   West    100    45        18
# 5    Feb      Tablet  Electronics  South    500   350         9
# 6    Mar      Webcam  Accessories   East     80    40        15
# 7    Mar     Printer       Office   West    250   180         8
# 8    Mar      Laptop  Electronics  North   1200   900         6
# 9    Apr       Mouse  Accessories  South     25    10        65
# 10   Apr    Keyboard  Accessories   East     75    35        25
# 11   Apr     Monitor  Electronics  North    300   200        14
# 12   May  Headphones  Accessories   West    100    45        22
# 13   May      Tablet  Electronics  South    500   350        11
# ...

# %% [markdown]
# ## Dataset Description
#
# The dataset contains monthly sales data.
#
# Columns:
#
# - Month: sales month
# - Product: product name
# - Category: product category
# - Region: sales region
# - Price: selling price per unit
# - Cost: cost per unit
# - Quantity: units sold

# %%
df.head()
# Out:
#   Month     Product     Category Region  Price  Cost  Quantity
# 0   Jan      Laptop  Electronics  North   1200   900         5
# 1   Jan       Mouse  Accessories  South     25    10        50
# 2   Jan    Keyboard  Accessories   East     75    35        20
# 3   Feb     Monitor  Electronics  North    300   200        12
# 4   Feb  Headphones  Accessories   West    100    45        18

# %%
df.shape
# Out:
# (18, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     18 non-null     object
#  1   Product   18 non-null     object
#  2   Category  18 non-null     object
#  3   Region    18 non-null     object
#  4   Price     18 non-null     int64
#  5   Cost      18 non-null     int64
#  6   Quantity  18 non-null     int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#              Price        Cost   Quantity
# count    18.000000   18.000000  18.000000
# mean    349.166667  246.111111  21.388889
# std     418.429311  319.883046  19.686182
# min      25.000000   10.000000   5.000000
# 25%      76.250000   36.250000   9.250000
# 50%     175.000000  112.500000  14.500000
# 75%     450.000000  312.500000  21.500000
# max    1200.000000  900.000000  70.000000

# %%
df["Revenue"]=df["Price"]*df["Quantity"]
df["Total_cost"]=df["Cost"]*df["Quantity"]
df["Profit"]=df["Revenue"]-df["Total_cost"]
df["Profit_Margin"]=(df["Profit"]/df["Revenue"]*100).round(2)

df
# Out:
#    Month     Product     Category Region  Price  Cost  Quantity  Revenue  \
# 0    Jan      Laptop  Electronics  North   1200   900         5     6000
# 1    Jan       Mouse  Accessories  South     25    10        50     1250
# 2    Jan    Keyboard  Accessories   East     75    35        20     1500
# 3    Feb     Monitor  Electronics  North    300   200        12     3600
# 4    Feb  Headphones  Accessories   West    100    45        18     1800
# 5    Feb      Tablet  Electronics  South    500   350         9     4500
# 6    Mar      Webcam  Accessories   East     80    40        15     1200
# 7    Mar     Printer       Office   West    250   180         8     2000
# 8    Mar      Laptop  Electronics  North   1200   900         6     7200
# 9    Apr       Mouse  Accessories  South     25    10        65     1625
# 10   Apr    Keyboard  Accessories   East     75    35        25     1875
# 11   Apr     Monitor  Electronics  North    300   200        14     4200
# ...

# %%
total_revenue = df["Revenue"].sum()
total_profit = df["Profit"].sum()
total_quantity = df["Quantity"].sum()
average_profit_margin = df["Profit_Margin"].mean().round(2)

print("Sales Dashboard Summary")
print("=" * 35)
print(f"Total Revenue: ${total_revenue}")
print(f"Total Profit: ${total_profit}")
print(f"Total Quantity Sold: {total_quantity}")
print(f"Average Profit Margin: {average_profit_margin}%")
# Out:
# Sales Dashboard Summary
# ...
# Total Revenue: $58540
# Total Profit: $20355
# Total Quantity Sold: 385
# Average Profit Margin: 41.91%

# %%
 product_revenue = df.groupby("Product")["Revenue"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=product_revenue.index, y=product_revenue.values)

plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insight
#
# Laptop generated the highest revenue because it has the highest selling price.

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=category_profit.index, y=category_profit.values)

plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.show()

# %% [markdown]
# ## Insight
#
# Electronics generated strong profit because products in this category have higher prices.

# %%
region_revenue = df.groupby("Region")["Revenue"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=region_revenue.index, y=region_revenue.values)

plt.title("Revenue by Region")
plt.xlabel("Region")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ## Insight
#
# The region with the highest revenue can be considered the strongest sales market.

# %%
month_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

monthly_revenue = df.groupby("Month")["Revenue"].sum().reindex(month_order)

plt.figure(figsize=(10, 5))
sns.lineplot(x=monthly_revenue.index, y=monthly_revenue.values, marker="o")

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ## Insight
#
# The monthly revenue trend shows how sales performance changes over time.

# %%
product_quantity = df.groupby("Product")["Quantity"].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=product_quantity.index, y=product_quantity.values)

plt.title("Quantity Sold by Product")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insight
#
# Mouse sold the highest quantity because it has a low price and is easy to sell in large volume.

# %%
category_revenue = df.groupby("Category")["Revenue"].sum()

plt.figure(figsize=(7, 7))
plt.pie(
    category_revenue,
    labels=category_revenue.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Revenue Share by CAtegory")
plt.show()

# %% [markdown]
# ## Insight
#
# This chart shows which category contributes the largest share of total revenue.

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Price",
    y="Quantity",
    hue="Category",
    size="Revenue",
    sizes=(50, 400)
)

plt.title("Price vs Quantity Sold")
plt.xlabel("Price")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ## Insight
#
# Lower-priced products tend to sell in higher quantities, while higher-priced products usually sell fewer units.

# %%
product_margin = df.groupby("Product")["Profit_Margin"].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=product_margin.index, y=product_margin.values)

plt.title("Average Profit Margin by Product")
plt.xlabel("Product")
plt.ylabel("Profit Margin(%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Insight
#
# Profit margin helps compare product efficiency, not just total revenue.

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

# Chart 1: Revenue by Product
sns.barplot(
    x=product_revenue.index,
    y=product_revenue.values,
    ax=axes[0, 0]
)
axes[0, 0].set_title("Revenue by Product")
axes[0, 0].set_xlabel("Product")
axes[0, 0].set_ylabel("Revenue")
axes[0, 0].tick_params(axis="x", rotation=45)

# Chart 2: Profit by Category
sns.barplot(
    x=category_profit.index,
    y=category_profit.values,
    ax=axes[0, 1]
)
axes[0, 1].set_title("Profit by Category")
axes[0, 1].set_xlabel("Category")
axes[0, 1].set_ylabel("Profit")

# Chart 3: Monthly Revenue Trend
sns.lineplot(
    x=monthly_revenue.index,
    y=monthly_revenue.values,
    marker="o",
    ax=axes[1, 0]
)
axes[1, 0].set_title("Monthly Revenue Trend")
axes[1, 0].set_xlabel("Month")
axes[1, 0].set_ylabel("Revenue")

# Chart 4: Revenue by Region
sns.barplot(
    x=region_revenue.index,
    y=region_revenue.values,
    ax=axes[1, 1]
)
axes[1, 1].set_title("Revenue by Region")
axes[1, 1].set_xlabel("Region")
axes[1, 1].set_ylabel("Revenue")

plt.suptitle("Sales Dashboard Overview", fontsize=18)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 10))

sns.barplot(x=product_revenue.index, y=product_revenue.values, ax=axes[0, 0])
axes[0, 0].set_title("Revenue by Product")
axes[0, 0].set_xlabel("Product")
axes[0, 0].set_ylabel("Revenue")
axes[0, 0].tick_params(axis="x",rotation=45)

sns.barplot(x=category_profit.index, y=category_profit.values, ax=axes[0, 1])
axes[0, 1].set_title("Profit by Category")
axes[0, 1].set_xlabel("Category")
axes[0, 1].set_ylabel("Profit")

sns.lineplot(x=monthly_revenue.index, y=monthly_revenue.values, marker="o", ax=axes[1, 1])
axes[1, 1].set_title("Revenue by Region")
axes[1, 1].set_xlabel("Region")
axes[1, 1].set_ylabel("Revenue")

plt.suptitle("Sales Dashboard Overview", fontsize=18)
plt.tight_layout()

plt.savefig("sales_dashboard_overvire.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
tig

# %%
df.to_csv("sales_dashboard_data.csv", index=False)

print("Sales dashboard data exported successfully.")
# Out:
# Sales dashboard data exported successfully.

# %% [markdown]
# ## Key Findings
#
# From this sales dashboard project, I found that:
#
# 1. Laptop generated the highest revenue.
# 2. Mouse had the highest quantity sold because of its low price.
# 3. Electronics was one of the strongest categories by revenue and profit.
# 4. Revenue performance varies by region.
# 5. Monthly revenue trend helps track business performance over time.
# 6. Profit margin is useful for comparing product efficiency.
#
# ## What I Learned
#
# In this project, I practiced:
#
# - Creating bar charts
# - Creating line charts
# - Creating pie charts
# - Creating scatter plots
# - Grouping data for visualization
# - Building a simple dashboard using subplots
# - Saving dashboard images
# - Writing business insights from charts
#
# ## Next Step
#
# The next step is to use a real dataset from Kaggle and create a full exploratory data analysis report.
